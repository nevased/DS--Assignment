# %% [markdown]
# ## Predicting turbine energy yield (TEY) using ambient variables as features.

# %% [markdown]
# ## Import libraries

# %%
import keras
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, cross_val_score
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline
from keras.models import Sequential
from keras.layers import Dense
import tensorflow as tf
tf.debugging.set_log_device_placement(False)
import warnings
warnings.filterwarnings('ignore')

# %%
# Generating reproducible results from same code
tf.random.set_seed(14)

# %%
raw = pd.read_csv("https://raw.githubusercontent.com//nevased//Data-Set-for-Assignment//main//gas_turbines.csv")
raw.head()
#TEY is the variable we should predict.
# Out:
#        AT      AP      AH    AFDP    GTEP     TIT     TAT     TEY     CDP  \
# 0  6.8594  1007.9  96.799  3.5000  19.663  1059.2  550.00  114.70  10.605
# 1  6.7850  1008.4  97.118  3.4998  19.728  1059.3  550.00  114.72  10.598
# 2  6.8977  1008.8  95.939  3.4824  19.779  1059.4  549.87  114.71  10.601
# 3  7.0569  1009.2  95.249  3.4805  19.792  1059.6  549.99  114.72  10.606
# 4  7.3978  1009.7  95.150  3.4976  19.765  1059.7  549.98  114.72  10.612
#
#        CO     NOX
# 0  3.1547  82.722
# 1  3.2363  82.776
# 2  3.2012  82.468
# 3  3.1923  82.670
# 4  3.2484  82.311

# %%
df = raw.copy()
df = df.drop(['AFDP','GTEP','TIT','TAT','CDP','CO','NOX'],axis=1)
df.head()
# Out:
#        AT      AP      AH     TEY
# 0  6.8594  1007.9  96.799  114.70
# 1  6.7850  1008.4  97.118  114.72
# 2  6.8977  1008.8  95.939  114.71
# 3  7.0569  1009.2  95.249  114.72
# 4  7.3978  1009.7  95.150  114.72

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15039 entries, 0 to 15038
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AT      15039 non-null  float64
#  1   AP      15039 non-null  float64
#  2   AH      15039 non-null  float64
#  3   TEY     15039 non-null  float64
# dtypes: float64(4)
# memory usage: 470.1 KB

# %%
df.describe()
# Out:
#                  AT           AP            AH           TEY
# count  15039.000000  15039.00000  15039.000000  15039.000000
# mean      17.764381   1013.19924     79.124174    134.188464
# std        7.574323      6.41076     13.793439     15.829717
# min        0.522300    985.85000     30.344000    100.170000
# 25%       11.408000   1008.90000     69.750000    127.985000
# 50%       18.186000   1012.80000     82.266000    133.780000
# 75%       23.862500   1016.90000     90.043500    140.895000
# max       34.929000   1034.20000    100.200000    174.610000

# %% [markdown]
# # Feature Analysis

# %% [markdown]
#  All features in the dataset can be used in model building. This is a Regression Problem.

# %% [markdown]
# # Train | Split dataset

# %%
X =df.iloc[:,:-1]
Y = df.iloc[:,-1]


X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size = 0.3)

# %% [markdown]
# A common mistake when configuring a neural network is to first normalize the data before splitting the data.

# %%
y_train=np.reshape(y_train.to_numpy(), (-1,1))
y_test=np.reshape(y_test.to_numpy(), (-1,1))

# %%
from sklearn.preprocessing import MinMaxScaler

scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()

print(scaler_x.fit(X_train))
xtrain_scale=scaler_x.transform(X_train)

print(scaler_x.fit(X_test))
xtest_scale=scaler_x.transform(X_test)

print(scaler_y.fit(y_train))
ytrain_scale=scaler_y.transform(y_train)

print(scaler_y.fit(y_test))
ytest_scale=scaler_y.transform(y_test)
# Out:
# MinMaxScaler()
# MinMaxScaler()
# MinMaxScaler()
# MinMaxScaler()

# %%
len(xtrain_scale)
# Out:
# 10527

# %% [markdown]
# # Neural Network Modelling

# %% [markdown]
# ### Building the Model

# %%
# create model
model1 = Sequential()
model1.add(Dense(4, input_dim=3, kernel_initializer='normal', activation='relu'))
model1.add(Dense(2106,kernel_initializer='normal', activation='relu'))
model1.add(Dense(1, activation='linear'))
# Compile model
model1.compile(loss='mean_squared_error', optimizer='adam', metrics=['mse','mae'])
# Fit the model
hist1 = model1.fit(xtrain_scale, ytrain_scale, validation_split=0.33, epochs=100, batch_size=150)
#At epoch 50, mse and mae just keeps oscillating back and forth
# Out:
# Epoch 1/100
# 48/48 [==============================] - 1s 10ms/step - loss: 0.0727 - mse: 0.0727 - mae: 0.2102 - val_loss: 0.0484 - val_mse: 0.0484 - val_mae: 0.1633
# Epoch 2/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0454 - mse: 0.0454 - mae: 0.1563 - val_loss: 0.0481 - val_mse: 0.0481 - val_mae: 0.1631
# Epoch 3/100
# 48/48 [==============================] - 0s 6ms/step - loss: 0.0450 - mse: 0.0450 - mae: 0.1545 - val_loss: 0.0478 - val_mse: 0.0478 - val_mae: 0.1618
# Epoch 4/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0447 - mse: 0.0447 - mae: 0.1536 - val_loss: 0.0478 - val_mse: 0.0478 - val_mae: 0.1635
# Epoch 5/100
# 48/48 [==============================] - 0s 4ms/step - loss: 0.0445 - mse: 0.0445 - mae: 0.1539 - val_loss: 0.0474 - val_mse: 0.0474 - val_mae: 0.1622
# Epoch 6/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0442 - mse: 0.0442 - mae: 0.1533 - val_loss: 0.0468 - val_mse: 0.0468 - val_mae: 0.1609
# Epoch 7/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0438 - mse: 0.0438 - mae: 0.1529 - val_loss: 0.0469 - val_mse: 0.0469 - val_mae: 0.1630
# Epoch 8/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0436 - mse: 0.0436 - mae: 0.1536 - val_loss: 0.0460 - val_mse: 0.0460 - val_mae: 0.1613
# Epoch 9/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0429 - mse: 0.0429 - mae: 0.1530 - val_loss: 0.0456 - val_mse: 0.0456 - val_mae: 0.1604
# Epoch 10/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0427 - mse: 0.0427 - mae: 0.1541 - val_loss: 0.0449 - val_mse: 0.0449 - val_mae: 0.1623
# Epoch 11/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0422 - mse: 0.0422 - mae: 0.1552 - val_loss: 0.0448 - val_mse: 0.0448 - val_mae: 0.1624
# Epoch 12/100
# 48/48 [==============================] - 0s 7ms/step - loss: 0.0417 - mse: 0.0417 - mae: 0.1559 - val_loss: 0.0438 - val_mse: 0.0438 - val_mae: 0.1632
# Epoch 13/100
# 48/48 [==============================] - 0s 8ms/step - loss: 0.0414 - mse: 0.0414 - mae: 0.1564 - val_loss: 0.0436 - val_mse: 0.0436 - val_mae: 0.1634
# Epoch 14/100
# 48/48 [==============================] - 0s 10ms/step - loss: 0.0414 - mse: 0.0414 - mae: 0.1569 - val_loss: 0.0441 - val_mse: 0.0441 - val_mae: 0.1683
# Epoch 15/100
# 48/48 [==============================] - 0s 8ms/step - loss: 0.0418 - mse: 0.0418 - mae: 0.1597 - val_loss: 0.0444 - val_mse: 0.0444 - val_mae: 0.1641
# Epoch 16/100
# 48/48 [==============================] - 1s 10ms/step - loss: 0.0411 - mse: 0.0411 - mae: 0.1582 - val_loss: 0.0430 - val_mse: 0.0430 - val_mae: 0.1647
# Epoch 17/100
# 48/48 [==============================] - 0s 10ms/step - loss: 0.0413 - mse: 0.0413 - mae: 0.1598 - val_loss: 0.0435 - val_mse: 0.0435 - val_mae: 0.1641
# Epoch 18/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0410 - mse: 0.0410 - mae: 0.1584 - val_loss: 0.0428 - val_mse: 0.0428 - val_mae: 0.1649
# Epoch 19/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0408 - mse: 0.0408 - mae: 0.1584 - val_loss: 0.0428 - val_mse: 0.0428 - val_mae: 0.1644
# Epoch 20/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0407 - mse: 0.0407 - mae: 0.1581 - val_loss: 0.0430 - val_mse: 0.0430 - val_mae: 0.1677
# Epoch 21/100
# 48/48 [==============================] - 0s 6ms/step - loss: 0.0407 - mse: 0.0407 - mae: 0.1587 - val_loss: 0.0428 - val_mse: 0.0428 - val_mae: 0.1666
# Epoch 22/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0413 - mse: 0.0413 - mae: 0.1599 - val_loss: 0.0425 - val_mse: 0.0425 - val_mae: 0.1651
# Epoch 23/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0405 - mse: 0.0405 - mae: 0.1595 - val_loss: 0.0424 - val_mse: 0.0424 - val_mae: 0.1641
# Epoch 24/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0409 - mse: 0.0409 - mae: 0.1595 - val_loss: 0.0423 - val_mse: 0.0423 - val_mae: 0.1650
# Epoch 25/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0408 - mse: 0.0408 - mae: 0.1594 - val_loss: 0.0423 - val_mse: 0.0423 - val_mae: 0.1649
# Epoch 26/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0402 - mse: 0.0402 - mae: 0.1574 - val_loss: 0.0433 - val_mse: 0.0433 - val_mae: 0.1656
# Epoch 27/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0413 - mse: 0.0413 - mae: 0.1595 - val_loss: 0.0422 - val_mse: 0.0422 - val_mae: 0.1650
# Epoch 28/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0402 - mse: 0.0402 - mae: 0.1591 - val_loss: 0.0423 - val_mse: 0.0423 - val_mae: 0.1654
# Epoch 29/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0401 - mse: 0.0401 - mae: 0.1579 - val_loss: 0.0421 - val_mse: 0.0421 - val_mae: 0.1643
# Epoch 30/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0401 - mse: 0.0401 - mae: 0.1577 - val_loss: 0.0420 - val_mse: 0.0420 - val_mae: 0.1638
# Epoch 31/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0402 - mse: 0.0402 - mae: 0.1579 - val_loss: 0.0419 - val_mse: 0.0419 - val_mae: 0.1635
# Epoch 32/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0397 - mse: 0.0397 - mae: 0.1572 - val_loss: 0.0438 - val_mse: 0.0438 - val_mae: 0.1673
# Epoch 33/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0401 - mse: 0.0401 - mae: 0.1586 - val_loss: 0.0417 - val_mse: 0.0417 - val_mae: 0.1637
# Epoch 34/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0397 - mse: 0.0397 - mae: 0.1572 - val_loss: 0.0426 - val_mse: 0.0426 - val_mae: 0.1645
# Epoch 35/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0396 - mse: 0.0396 - mae: 0.1568 - val_loss: 0.0418 - val_mse: 0.0418 - val_mae: 0.1635
# Epoch 36/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0395 - mse: 0.0395 - mae: 0.1568 - val_loss: 0.0420 - val_mse: 0.0420 - val_mae: 0.1638
# Epoch 37/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0396 - mse: 0.0396 - mae: 0.1573 - val_loss: 0.0421 - val_mse: 0.0421 - val_mae: 0.1642
# Epoch 38/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0397 - mse: 0.0397 - mae: 0.1575 - val_loss: 0.0416 - val_mse: 0.0416 - val_mae: 0.1636
# Epoch 39/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0395 - mse: 0.0395 - mae: 0.1573 - val_loss: 0.0414 - val_mse: 0.0414 - val_mae: 0.1634
# Epoch 40/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0394 - mse: 0.0394 - mae: 0.1572 - val_loss: 0.0445 - val_mse: 0.0445 - val_mae: 0.1692
# Epoch 41/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0403 - mse: 0.0403 - mae: 0.1592 - val_loss: 0.0419 - val_mse: 0.0419 - val_mae: 0.1637
# Epoch 42/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0394 - mse: 0.0394 - mae: 0.1570 - val_loss: 0.0415 - val_mse: 0.0415 - val_mae: 0.1633
# Epoch 43/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0406 - mse: 0.0406 - mae: 0.1604 - val_loss: 0.0416 - val_mse: 0.0416 - val_mae: 0.1635
# Epoch 44/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0398 - mse: 0.0398 - mae: 0.1582 - val_loss: 0.0417 - val_mse: 0.0417 - val_mae: 0.1633
# Epoch 45/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0394 - mse: 0.0394 - mae: 0.1571 - val_loss: 0.0416 - val_mse: 0.0416 - val_mae: 0.1635
# Epoch 46/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0394 - mse: 0.0394 - mae: 0.1575 - val_loss: 0.0414 - val_mse: 0.0414 - val_mae: 0.1633
# Epoch 47/100
# 48/48 [==============================] - 0s 8ms/step - loss: 0.0393 - mse: 0.0393 - mae: 0.1570 - val_loss: 0.0418 - val_mse: 0.0418 - val_mae: 0.1642
# Epoch 48/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0394 - mse: 0.0394 - mae: 0.1572 - val_loss: 0.0414 - val_mse: 0.0414 - val_mae: 0.1640
# Epoch 49/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0393 - mse: 0.0393 - mae: 0.1573 - val_loss: 0.0417 - val_mse: 0.0417 - val_mae: 0.1652
# Epoch 50/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0395 - mse: 0.0395 - mae: 0.1576 - val_loss: 0.0414 - val_mse: 0.0414 - val_mae: 0.1632
# Epoch 51/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0396 - mse: 0.0396 - mae: 0.1581 - val_loss: 0.0413 - val_mse: 0.0413 - val_mae: 0.1634
# Epoch 52/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0394 - mse: 0.0394 - mae: 0.1571 - val_loss: 0.0413 - val_mse: 0.0413 - val_mae: 0.1630
# Epoch 53/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0393 - mse: 0.0393 - mae: 0.1570 - val_loss: 0.0427 - val_mse: 0.0427 - val_mae: 0.1657
# Epoch 54/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0394 - mse: 0.0394 - mae: 0.1566 - val_loss: 0.0413 - val_mse: 0.0413 - val_mae: 0.1630
# Epoch 55/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0393 - mse: 0.0393 - mae: 0.1572 - val_loss: 0.0429 - val_mse: 0.0429 - val_mae: 0.1662
# Epoch 56/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0394 - mse: 0.0394 - mae: 0.1579 - val_loss: 0.0413 - val_mse: 0.0413 - val_mae: 0.1635
# Epoch 57/100
# 48/48 [==============================] - 0s 9ms/step - loss: 0.0411 - mse: 0.0411 - mae: 0.1617 - val_loss: 0.0418 - val_mse: 0.0418 - val_mae: 0.1634
# Epoch 58/100
# 48/48 [==============================] - 0s 8ms/step - loss: 0.0394 - mse: 0.0394 - mae: 0.1569 - val_loss: 0.0415 - val_mse: 0.0415 - val_mae: 0.1638
# Epoch 59/100
# 48/48 [==============================] - 0s 10ms/step - loss: 0.0404 - mse: 0.0404 - mae: 0.1592 - val_loss: 0.0418 - val_mse: 0.0418 - val_mae: 0.1634
# Epoch 60/100
# 48/48 [==============================] - 0s 10ms/step - loss: 0.0393 - mse: 0.0393 - mae: 0.1571 - val_loss: 0.0417 - val_mse: 0.0417 - val_mae: 0.1640
# Epoch 61/100
# 48/48 [==============================] - 0s 8ms/step - loss: 0.0396 - mse: 0.0396 - mae: 0.1579 - val_loss: 0.0413 - val_mse: 0.0413 - val_mae: 0.1635
# Epoch 62/100
# 48/48 [==============================] - 0s 8ms/step - loss: 0.0392 - mse: 0.0392 - mae: 0.1572 - val_loss: 0.0416 - val_mse: 0.0416 - val_mae: 0.1636
# Epoch 63/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0395 - mse: 0.0395 - mae: 0.1574 - val_loss: 0.0419 - val_mse: 0.0419 - val_mae: 0.1642
# Epoch 64/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0408 - mse: 0.0408 - mae: 0.1603 - val_loss: 0.0417 - val_mse: 0.0417 - val_mae: 0.1641
# Epoch 65/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0396 - mse: 0.0396 - mae: 0.1587 - val_loss: 0.0412 - val_mse: 0.0412 - val_mae: 0.1636
# Epoch 66/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0394 - mse: 0.0394 - mae: 0.1576 - val_loss: 0.0413 - val_mse: 0.0413 - val_mae: 0.1636
# Epoch 67/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0392 - mse: 0.0392 - mae: 0.1567 - val_loss: 0.0417 - val_mse: 0.0417 - val_mae: 0.1649
# Epoch 68/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0394 - mse: 0.0394 - mae: 0.1580 - val_loss: 0.0422 - val_mse: 0.0422 - val_mae: 0.1648
# Epoch 69/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0396 - mse: 0.0396 - mae: 0.1582 - val_loss: 0.0416 - val_mse: 0.0416 - val_mae: 0.1647
# Epoch 70/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0393 - mse: 0.0393 - mae: 0.1575 - val_loss: 0.0413 - val_mse: 0.0413 - val_mae: 0.1634
# Epoch 71/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0394 - mse: 0.0394 - mae: 0.1565 - val_loss: 0.0417 - val_mse: 0.0417 - val_mae: 0.1633
# Epoch 72/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0395 - mse: 0.0395 - mae: 0.1575 - val_loss: 0.0413 - val_mse: 0.0413 - val_mae: 0.1634
# Epoch 73/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0393 - mse: 0.0393 - mae: 0.1570 - val_loss: 0.0415 - val_mse: 0.0415 - val_mae: 0.1634
# Epoch 74/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0393 - mse: 0.0393 - mae: 0.1575 - val_loss: 0.0421 - val_mse: 0.0421 - val_mae: 0.1662
# Epoch 75/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0398 - mse: 0.0398 - mae: 0.1586 - val_loss: 0.0416 - val_mse: 0.0416 - val_mae: 0.1635
# Epoch 76/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0393 - mse: 0.0393 - mae: 0.1567 - val_loss: 0.0413 - val_mse: 0.0413 - val_mae: 0.1631
# Epoch 77/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0397 - mse: 0.0397 - mae: 0.1577 - val_loss: 0.0413 - val_mse: 0.0413 - val_mae: 0.1629
# Epoch 78/100
# 48/48 [==============================] - 0s 7ms/step - loss: 0.0393 - mse: 0.0393 - mae: 0.1568 - val_loss: 0.0418 - val_mse: 0.0418 - val_mae: 0.1650
# Epoch 79/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0396 - mse: 0.0396 - mae: 0.1580 - val_loss: 0.0413 - val_mse: 0.0413 - val_mae: 0.1630
# Epoch 80/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0393 - mse: 0.0393 - mae: 0.1573 - val_loss: 0.0415 - val_mse: 0.0415 - val_mae: 0.1639
# Epoch 81/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0396 - mse: 0.0396 - mae: 0.1575 - val_loss: 0.0423 - val_mse: 0.0423 - val_mae: 0.1648
# Epoch 82/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0393 - mse: 0.0393 - mae: 0.1570 - val_loss: 0.0422 - val_mse: 0.0422 - val_mae: 0.1666
# Epoch 83/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0397 - mse: 0.0397 - mae: 0.1584 - val_loss: 0.0414 - val_mse: 0.0414 - val_mae: 0.1629
# Epoch 84/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0393 - mse: 0.0393 - mae: 0.1572 - val_loss: 0.0413 - val_mse: 0.0413 - val_mae: 0.1631
# Epoch 85/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0393 - mse: 0.0393 - mae: 0.1573 - val_loss: 0.0418 - val_mse: 0.0418 - val_mae: 0.1652
# Epoch 86/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0397 - mse: 0.0397 - mae: 0.1578 - val_loss: 0.0414 - val_mse: 0.0414 - val_mae: 0.1635
# Epoch 87/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0395 - mse: 0.0395 - mae: 0.1573 - val_loss: 0.0419 - val_mse: 0.0419 - val_mae: 0.1647
# Epoch 88/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0396 - mse: 0.0396 - mae: 0.1570 - val_loss: 0.0417 - val_mse: 0.0417 - val_mae: 0.1631
# Epoch 89/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0397 - mse: 0.0397 - mae: 0.1578 - val_loss: 0.0413 - val_mse: 0.0413 - val_mae: 0.1630
# Epoch 90/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0394 - mse: 0.0394 - mae: 0.1575 - val_loss: 0.0430 - val_mse: 0.0430 - val_mae: 0.1666
# Epoch 91/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0406 - mse: 0.0406 - mae: 0.1611 - val_loss: 0.0414 - val_mse: 0.0414 - val_mae: 0.1649
# Epoch 92/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0394 - mse: 0.0394 - mae: 0.1581 - val_loss: 0.0415 - val_mse: 0.0415 - val_mae: 0.1646
# Epoch 93/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0397 - mse: 0.0397 - mae: 0.1582 - val_loss: 0.0416 - val_mse: 0.0416 - val_mae: 0.1636
# Epoch 94/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0394 - mse: 0.0394 - mae: 0.1577 - val_loss: 0.0413 - val_mse: 0.0413 - val_mae: 0.1639
# Epoch 95/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0394 - mse: 0.0394 - mae: 0.1584 - val_loss: 0.0412 - val_mse: 0.0412 - val_mae: 0.1635
# Epoch 96/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0393 - mse: 0.0393 - mae: 0.1572 - val_loss: 0.0412 - val_mse: 0.0412 - val_mae: 0.1634
# Epoch 97/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0393 - mse: 0.0393 - mae: 0.1578 - val_loss: 0.0412 - val_mse: 0.0412 - val_mae: 0.1635
# Epoch 98/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0392 - mse: 0.0392 - mae: 0.1570 - val_loss: 0.0412 - val_mse: 0.0412 - val_mae: 0.1634
# Epoch 99/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0392 - mse: 0.0392 - mae: 0.1575 - val_loss: 0.0412 - val_mse: 0.0412 - val_mae: 0.1635
# Epoch 100/100
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0394 - mse: 0.0394 - mae: 0.1583 - val_loss: 0.0414 - val_mse: 0.0414 - val_mae: 0.1639

# %%
model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 4)                 16
#
#  dense_1 (Dense)             (None, 2106)              10530
#
#  dense_2 (Dense)             (None, 1)                 2107
#
# =================================================================
# Total params: 12653 (49.43 KB)
# Trainable params: 12653 (49.43 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # Model Evaluation

# %%
y_predict = model1.predict(xtest_scale)
# Out:
# 141/141 [==============================] - 0s 1ms/step

# %%
print(hist1.history.keys())
# Out:
# dict_keys(['loss', 'mse', 'mae', 'val_loss', 'val_mse', 'val_mae'])

# %%
hist1_df = pd.DataFrame(hist1.history)
hist1_df["epoch"]=hist1.epoch
hist1_df.tail()
# Out:
#         loss       mse       mae  val_loss   val_mse   val_mae  epoch
# 95  0.039269  0.039269  0.157234  0.041234  0.041234  0.163368     95
# 96  0.039327  0.039327  0.157770  0.041211  0.041211  0.163463     96
# 97  0.039183  0.039183  0.156967  0.041222  0.041222  0.163421     97
# 98  0.039225  0.039225  0.157459  0.041190  0.041190  0.163479     98
# 99  0.039358  0.039358  0.158309  0.041369  0.041369  0.163905     99

# %% [markdown]
# # Visualize Training History

# %%
# summarize history for Loss

sns.set(rc={'figure.figsize':(6,4)})

plt.plot(hist1.history['loss'])
plt.plot(hist1.history['val_loss'])
plt.title('model1 loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# summarize history for loss
plt.plot(hist1.history['mse'])
plt.plot(hist1.history['val_mse'])
plt.title('model1 mse')
plt.ylabel('mse')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
